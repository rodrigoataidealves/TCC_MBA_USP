# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigoataidealves/TCC_MBA_USP/blob/main/02_Despesas_Visao_Siconfi_Bimestre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===========================
# Extração, leitura robusta e filtros
# ===========================

# from google.colab import files
# files.upload()  # se precisar fazer upload do ZIP

import os, zipfile, glob, pathlib, re, unicodedata
import pandas as pd

from google.colab import data_table, files
data_table.enable_dataframe_formatter()

ZIP_PATH = '/content/2025_1bi_mun_desp.zip'        # ajuste se necessário
EXTRACT_DIR = '/content/dados_2025_1bi_mun_desp'
OUT_XLSX = '/content/2025_1bi_mun_desp_filtrado.xlsx'

# 1) Extrair ZIP
os.makedirs(EXTRACT_DIR, exist_ok=True)
with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_DIR)
print('Arquivos extraídos para:', EXTRACT_DIR)

# 2) Listar candidatos tabulares
candidates = []
for ext in ('*.csv','*.txt','*.xlsx','*.xls','*.parquet'):
    candidates.extend(glob.glob(os.path.join(EXTRACT_DIR, '**', ext), recursive=True))

if not candidates:
    raise FileNotFoundError('Nenhum arquivo CSV/TXT/Excel/Parquet encontrado no ZIP.')

print(f'{len(candidates)} arquivo(s) tabulares encontrado(s).')
for i, p in enumerate(candidates[:10], 1):
    print(f'[{i}]', p)
print('...')

# ------------------------
# Funções utilitárias
# ------------------------
def normalize_text(s:str) -> str:
    """normaliza texto: sem acento, minúsculo e só letras/números/espacos"""
    s = unicodedata.normalize('NFKD', str(s))
    s = ''.join(ch for ch in s if not unicodedata.combining(ch))
    s = s.lower()
    s = re.sub(r'[^a-z0-9]+', ' ', s)
    return s.strip()

def columns_norm_map(df: pd.DataFrame):
    """retorna dict: coluna_normalizada -> nome_original"""
    m = {}
    for c in df.columns:
        m[normalize_text(c)] = c
    return m

def try_read_csv_like(path):
    """Lê CSV/TXT tentando detectar separador, encoding e linha de cabeçalho."""
    # tentativas de encoding e linhas a pular (para ignorar capas/metadata)
    encodings = ['latin-1', 'utf-8', 'utf-8-sig']
    for enc in encodings:
        # tenta inferir o separador (sep=None + engine='python')
        for skip in range(0, 30):
            try:
                df = pd.read_csv(path, sep=None, engine='python', encoding=enc, skiprows=skip)
                # rejeita leitura trivial com 1 coluna e muitas linhas (sinal de separador errado)
                if df.shape[1] == 1 and df.shape[0] > 5:
                    continue
                return df
            except Exception:
                continue
    # fallback (pode vir 1 coluna; ainda assim retornaremos)
    try:
        return pd.read_csv(path, sep=None, engine='python', encoding='latin-1')
    except Exception:
        return pd.read_csv(path, encoding='latin-1')

def try_read_excel_like(path):
    """Lê Excel tentando encontrar a sheet e o offset de cabeçalho corretos."""
    xls = pd.ExcelFile(path)
    # percorre sheets e tenta pular de 0 a 30 linhas até achar header plausível
    for sheet in xls.sheet_names:
        for skip in range(0, 30):
            try:
                df = pd.read_excel(path, sheet_name=sheet, skiprows=skip)
                # descarta leituras vazias ou 1 coluna com muitas linhas (sheet de capa)
                if df is None or df.empty:
                    continue
                if df.shape[1] == 1 and df.shape[0] > 5:
                    continue
                return df, sheet, skip
            except Exception:
                continue
    # fallback: primeira sheet sem skip
    return pd.read_excel(path), xls.sheet_names[0], 0

def load_table(path):
    suf = pathlib.Path(path).suffix.lower()
    if suf in ('.csv', '.txt'):
        return try_read_csv_like(path), {'source': path, 'sheet': None, 'skiprows': None}
    elif suf in ('.xlsx', '.xls'):
        df, sheet, skip = try_read_excel_like(path)
        return df, {'source': path, 'sheet': sheet, 'skiprows': skip}
    elif suf == '.parquet':
        return pd.read_parquet(path), {'source': path, 'sheet': None, 'skiprows': None}
    else:
        raise ValueError(f'Formato não suportado: {suf}')

def find_col_by_candidates(df, candidates_norm:set):
    """Encontra a 1ª coluna cujo nome normalizado está no conjunto candidates_norm."""
    cmap = columns_norm_map(df)
    for norm_name, original in cmap.items():
        if norm_name in candidates_norm:
            return original
    raise KeyError(f"Nenhuma das colunas {sorted(list(candidates_norm))} foi encontrada.\n"
                   f"Colunas disponíveis: {list(df.columns)}")

# ------------------------
# 3) Abrir o MELHOR candidato
#     - tentaremos na ordem dos arquivos; se o 1º não tiver as colunas-alvo, testamos os demais
# ------------------------
targets_ok = False
chosen_info = None
for path in candidates:
    df_try, info = load_table(path)
    # normaliza cabeçalhos (sem renomear ainda)
    cmap = columns_norm_map(df_try)
    # Procuramos as colunas necessárias:
    #  - "coluna" (ex.: valores como "DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)")
    #  - "conta" OU "função"/"funcao" (muitos arquivos usam "Função")
    try:
        col_coluna = find_col_by_candidates(df_try, {'coluna'})
        col_conta  = find_col_by_candidates(df_try, {'conta', 'funcao', 'funcao orcamentaria', 'funcaoo', 'funcao classificacao', 'funcao despesa', 'funcao  '})
        # Se chegamos até aqui, este arquivo serve
        df = df_try
        chosen_info = info
        targets_ok = True
        break
    except KeyError:
        continue

if not targets_ok:
    # feedback para diagnóstico
    print("Nenhum arquivo com colunas 'coluna' e ('conta' ou 'função') foi encontrado diretamente.")
    print("Mostrando colunas do primeiro candidato para inspeção manual:")
    df_dbg, info_dbg = load_table(candidates[0])
    print(df_dbg.columns.tolist()[:50])
    raise KeyError("Não foi possível localizar as colunas necessárias. "
                   "Verifique se o dataset possui campos 'coluna' e 'conta' (ou 'função').")

print("Arquivo selecionado:", chosen_info['source'])
if chosen_info['sheet'] is not None:
    print("Planilha:", chosen_info['sheet'], "| skiprows:", chosen_info['skiprows'])
print("Dimensão bruta:", df.shape)

# ------------------------
# 4) Preparar filtros (case/acentos-agnósticos)
# ------------------------
def norm_series(s):
    return s.astype(str).map(normalize_text)

# localizar nomes originais novamente (garantia)
col_coluna = find_col_by_candidates(df, {'coluna'})
col_conta  = find_col_by_candidates(df, {'conta', 'funcao'})

# alvo da coluna "coluna"
alvo_coluna_norm = normalize_text('DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)')

# valores aceitos na "Conta" (ou "Função")
contas_desejadas = ['Assistência Social', 'Previdência Social', 'Saúde', 'Educação', 'Encargos Especiais']
contas_norm_set  = { normalize_text(v) for v in contas_desejadas }

# cria colunas normalizadas temporárias para filtrar
col_coluna_norm = '__col_coluna_norm__'
col_conta_norm  = '__col_conta_norm__'

df[col_coluna_norm] = norm_series(df[col_coluna])
df[col_conta_norm]  = norm_series(df[col_conta])

mask = (df[col_coluna_norm] == alvo_coluna_norm) & (df[col_conta_norm].isin(contas_norm_set))
df_filtrado = df.loc[mask].drop(columns=[col_coluna_norm, col_conta_norm])

print("Registros após filtro:", df_filtrado.shape)

# Visualizar amostra
display(df_filtrado.head(50))

# ------------------------
# 5) Exportar Excel e disponibilizar download
# ------------------------
with pd.ExcelWriter(OUT_XLSX, engine='openpyxl') as xlw:
    df_filtrado.to_excel(xlw, index=False, sheet_name='filtrado')

print("Arquivo Excel salvo em:", OUT_XLSX)
files.download(OUT_XLSX)
# Out:
# Arquivos extraídos para: /content/dados_2025_1bi_mun_desp
# 1 arquivo(s) tabulares encontrado(s).
# [1] /content/dados_2025_1bi_mun_desp/finbraRREO.csv
# ...
# Arquivo selecionado: /content/dados_2025_1bi_mun_desp/finbraRREO.csv
# Dimensão bruta: (2750317, 8)
# Registros após filtro: (23481, 8)
#                                             Instituição  Cod.IBGE  UF  \
# 380   Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 383   Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 385   Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 393   Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 416   Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 886        Prefeitura Municipal de Arroio do Tigre - RS   4301206  RS
# 889        Prefeitura Municipal de Arroio do Tigre - RS   4301206  RS
# 895        Prefeitura Municipal de Arroio do Tigre - RS   4301206  RS
# 922        Prefeitura Municipal de Arroio do Tigre - RS   4301206  RS
# 1425      Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 1429      Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 1431      Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 1436      Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 1462      Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 2116          Prefeitura Municipal de Ponta Grossa - PR   4119905  PR
# 2122          Prefeitura Municipal de Ponta Grossa - PR   4119905  PR
# 2133          Prefeitura Municipal de Ponta Grossa - PR   4119905  PR
# 2161          Prefeitura Municipal de Ponta Grossa - PR   4119905  PR
# 2595          Prefeitura Municipal de José Boiteux - SC   4209151  SC
# 2599          Prefeitura Municipal de José Boiteux - SC   4209151  SC
# 2601          Prefeitura Municipal de José Boiteux - SC   4209151  SC
# 3065      Prefeitura Municipal de Liberato Salzano - RS   4311601  RS
# 3068      Prefeitura Municipal de Liberato Salzano - RS   4311601  RS
# 3070      Prefeitura Municipal de Liberato Salzano - RS   4311601  RS
# 3074      Prefeitura Municipal de Liberato Salzano - RS   4311601  RS
# 3724           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 3729           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 3732           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 3737           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 3765           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 4256  Prefeitura Municipal de Monte Alegre dos Campo...   4312377  RS
# 4260  Prefeitura Municipal de Monte Alegre dos Campo...   4312377  RS
# 4265  Prefeitura Municipal de Monte Alegre dos Campo...   4312377  RS
# 4285  Prefeitura Municipal de Monte Alegre dos Campo...   4312377  RS
# 4768       Prefeitura Municipal de Três Cachoeiras - RS   4321667  RS
# 4774       Prefeitura Municipal de Três Cachoeiras - RS   4321667  RS
# 4779       Prefeitura Municipal de Três Cachoeiras - RS   4321667  RS
# 4804       Prefeitura Municipal de Três Cachoeiras - RS   4321667  RS
# 5252        Prefeitura Municipal de Guarujá do Sul - SC   4206603  SC
# 5256        Prefeitura Municipal de Guarujá do Sul - SC   4206603  SC
# 5260        Prefeitura Municipal de Guarujá do Sul - SC   4206603  SC
# 5280        Prefeitura Municipal de Guarujá do Sul - SC   4206603  SC
# 5739    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 5742    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 5744    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 5750    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 5770    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 6244               Prefeitura Municipal de Gaurama - RS   4308706  RS
# 6249               Prefeitura Municipal de Gaurama - RS   4308706  RS
# 6251               Prefeitura Municipal de Gaurama - RS   4308706  RS
#
#       População                                  Coluna               Conta  \
# 380        8070  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 383        8070  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 385        8070  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 393        8070  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 416        8070  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 886       12022  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 889       12022  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 895       12022  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 922       12022  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 1425       3468  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 1429       3468  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 1431       3468  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 1436       3468  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 1462       3468  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 2116     391654  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 2122     391654  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 2133     391654  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 2161     391654  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 2595       5991  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 2599       5991  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 2601       5991  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 3065       4664  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 3068       4664  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 3070       4664  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 3074       4664  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 3724     144165  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 3729     144165  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 3732     144165  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 3737     144165  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 3765     144165  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 4256       3610  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 4260       3610  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 4265       3610  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 4285       3610  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 4768      11551  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 4774      11551  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 4779      11551  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 4804      11551  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 5252       4819  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 5256       4819  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 5260       4819  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 5280       4819  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 5739       2547  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 5742       2547  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 5744       2547  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
# 5750       2547  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)            Educação
# 5770       2547  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Encargos Especiais
# 6244       5676  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Assistência Social
# 6249       5676  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)  Previdência Social
# 6251       5676  DESPESAS LIQUIDADAS ATÉ O BIMESTRE (d)               Saúde
#
#               Identificador da Conta        Valor
# 380   siconfi-cor_RREO2TotalDespesas    248631,62
# 383   siconfi-cor_RREO2TotalDespesas     85886,04
# 385   siconfi-cor_RREO2TotalDespesas   2337545,18
# 393   siconfi-cor_RREO2TotalDespesas   2148879,72
# 416   siconfi-cor_RREO2TotalDespesas     123747,8
# 886   siconfi-cor_RREO2TotalDespesas    211013,37
# 889   siconfi-cor_RREO2TotalDespesas   2117988,72
# 895   siconfi-cor_RREO2TotalDespesas   2329540,75
# 922   siconfi-cor_RREO2TotalDespesas    507993,13
# 1425  siconfi-cor_RREO2TotalDespesas     35393,33
# 1429  siconfi-cor_RREO2TotalDespesas    658010,58
# 1431  siconfi-cor_RREO2TotalDespesas    977738,09
# 1436  siconfi-cor_RREO2TotalDespesas    633405,04
# 1462  siconfi-cor_RREO2TotalDespesas    441968,39
# 2116  siconfi-cor_RREO2TotalDespesas   9208391,04
# 2122  siconfi-cor_RREO2TotalDespesas  31422844,49
# 2133  siconfi-cor_RREO2TotalDespesas  70926737,69
# 2161  siconfi-cor_RREO2TotalDespesas  30537225,58
# 2595  siconfi-cor_RREO2TotalDespesas    295945,89
# 2599  siconfi-cor_RREO2TotalDespesas   1265036,67
# 2601  siconfi-cor_RREO2TotalDespesas    1805279,7
# 3065  siconfi-cor_RREO2TotalDespesas     99320,65
# 3068  siconfi-cor_RREO2TotalDespesas    562299,39
# 3070  siconfi-cor_RREO2TotalDespesas    959193,14
# 3074  siconfi-cor_RREO2TotalDespesas    805790,22
# 3724  siconfi-cor_RREO2TotalDespesas   1883240,15
# 3729  siconfi-cor_RREO2TotalDespesas  11929419,92
# 3732  siconfi-cor_RREO2TotalDespesas   14989125,1
# 3737  siconfi-cor_RREO2TotalDespesas  19972531,09
# 3765  siconfi-cor_RREO2TotalDespesas   4697095,96
# 4256  siconfi-cor_RREO2TotalDespesas    254728,05
# 4260  siconfi-cor_RREO2TotalDespesas   1058767,54
# 4265  siconfi-cor_RREO2TotalDespesas   1070671,94
# 4285  siconfi-cor_RREO2TotalDespesas     56492,97
# 4768  siconfi-cor_RREO2TotalDespesas    262349,97
# 4774  siconfi-cor_RREO2TotalDespesas   2209487,98
# 4779  siconfi-cor_RREO2TotalDespesas   2899816,88
# 4804  siconfi-cor_RREO2TotalDespesas    632554,29
# 5252  siconfi-cor_RREO2TotalDespesas    191341,82
# 5256  siconfi-cor_RREO2TotalDespesas    990694,08
# 5260  siconfi-cor_RREO2TotalDespesas   1470295,24
# 5280  siconfi-cor_RREO2TotalDespesas    360281,51
# 5739  siconfi-cor_RREO2TotalDespesas      28554,1
# 5742  siconfi-cor_RREO2TotalDespesas    281039,17
# 5744  siconfi-cor_RREO2TotalDespesas    613375,95
# 5750  siconfi-cor_RREO2TotalDespesas    689447,01
# 5770  siconfi-cor_RREO2TotalDespesas     99121,36
# 6244  siconfi-cor_RREO2TotalDespesas    270229,96
# 6249  siconfi-cor_RREO2TotalDespesas     81614,22
# 6251  siconfi-cor_RREO2TotalDespesas   1276249,55
# Arquivo Excel salvo em: /content/2025_1bi_mun_desp_filtrado.xlsx
