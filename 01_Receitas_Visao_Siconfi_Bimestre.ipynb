# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigoataidealves/TCC_MBA_USP/blob/main/01_Receitas_Visao_Siconfi_Bimestre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===========================
# Extração, leitura robusta e filtros (Receitas)
# Com download automático ao final (Colab) e link (Jupyter)
# ===========================

import os, zipfile, glob, pathlib, re, unicodedata, sys
import pandas as pd

# Detectar Colab/Jupyter e configurar exibição
IN_COLAB = False
colab_files = None
try:
    from google.colab import data_table, files as colab_files
    data_table.enable_dataframe_formatter()
    IN_COLAB = True
except Exception:
    pass

try:
    from IPython.display import display, FileLink
except Exception:
    def display(*args, **kwargs):
        # ambiente sem IPython; não faz nada
        return

# ===========================
# Caminhos (ajuste se necessário)
# ===========================
ZIP_PATH    = '/content/2025_1bi_mun_rec.zip'            # <-- ajuste se necessário
EXTRACT_DIR = '/content/dados_2025_1bi_mun_rec'          # <-- ajuste se necessário
OUT_XLSX    = '/content/DFLUX_Tabela_ManualPDG.xlsx'     # <-- nome padrão preferido

# 1) Extrair ZIP
os.makedirs(EXTRACT_DIR, exist_ok=True)
with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_DIR)
print('Arquivos extraídos para:', EXTRACT_DIR)

# 2) Listar candidatos tabulares
candidates = []
for ext in ('*.csv', '*.txt', '*.xlsx', '*.xls', '*.parquet'):
    candidates.extend(glob.glob(os.path.join(EXTRACT_DIR, '**', ext), recursive=True))

if not candidates:
    raise FileNotFoundError('Nenhum arquivo CSV/TXT/Excel/Parquet encontrado no ZIP.')

print(f'{len(candidates)} arquivo(s) tabulares encontrado(s).')
for i, p in enumerate(candidates[:10], 1):
    print(f'[{i}]', p)
print('...')

# ------------------------
# Funções utilitárias
# ------------------------
def normalize_text(s: str) -> str:
    """Normaliza texto: sem acento, minúsculo e só letras/números/espaços."""
    s = unicodedata.normalize('NFKD', str(s))
    s = ''.join(ch for ch in s if not unicodedata.combining(ch))
    s = s.lower()
    s = re.sub(r'[^a-z0-9]+', ' ', s)
    return s.strip()

def columns_norm_map(df: pd.DataFrame):
    """Retorna dict: nome_normalizado -> nome_original."""
    m = {}
    for c in df.columns:
        m[normalize_text(c)] = c
    return m

def try_read_csv_like(path):
    """Lê CSV/TXT detectando separador/encoding e pulando linhas de capa."""
    encodings = ['latin-1', 'utf-8', 'utf-8-sig']
    for enc in encodings:
        for skip in range(0, 30):
            try:
                df = pd.read_csv(path, sep=None, engine='python', encoding=enc, skiprows=skip)
                if df.shape[1] == 1 and df.shape[0] > 5:
                    continue  # provavelmente separador errado ou capa
                return df
            except Exception:
                continue
    # fallback
    try:
        return pd.read_csv(path, sep=None, engine='python', encoding='latin-1')
    except Exception:
        return pd.read_csv(path, encoding='latin-1')

def try_read_excel_like(path):
    """Lê Excel tentando sheet e offset corretos para o cabeçalho."""
    xls = pd.ExcelFile(path)
    for sheet in xls.sheet_names:
        for skip in range(0, 30):
            try:
                df = pd.read_excel(path, sheet_name=sheet, skiprows=skip)
                if df is None or df.empty:
                    continue
                if df.shape[1] == 1 and df.shape[0] > 5:
                    continue  # sheet de capa
                return df, sheet, skip
            except Exception:
                continue
    return pd.read_excel(path), xls.sheet_names[0], 0

def load_table(path):
    suf = pathlib.Path(path).suffix.lower()
    if suf in ('.csv', '.txt'):
        return try_read_csv_like(path), {'source': path, 'sheet': None, 'skiprows': None}
    elif suf in ('.xlsx', '.xls'):
        df, sheet, skip = try_read_excel_like(path)
        return df, {'source': path, 'sheet': sheet, 'skiprows': skip}
    elif suf == '.parquet':
        return pd.read_parquet(path), {'source': path, 'sheet': None, 'skiprows': None}
    else:
        raise ValueError(f'Formato não suportado: {suf}')

def find_col_by_candidates(df, candidates_norm: set):
    """Encontra a 1ª coluna cujo nome normalizado esteja em candidates_norm."""
    cmap = columns_norm_map(df)
    for norm_name, original in cmap.items():
        if norm_name in candidates_norm:
            return original
    raise KeyError(
        f"Nenhuma das colunas {sorted(list(candidates_norm))} foi encontrada.\n"
        f"Colunas disponíveis: {list(df.columns)}"
    )

# ------------------------
# 3) Abrir o MELHOR candidato
#    - percorre arquivos até achar colunas 'coluna' e 'conta'
# ------------------------
targets_ok = False
chosen_info = None
for path in candidates:
    df_try, info = load_table(path)
    try:
        # Procuramos:
        #  - "coluna" (onde fica 'Até o Bimestre (c)')
        #  - "conta" (onde fica 'RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)')
        col_coluna = find_col_by_candidates(df_try, {'coluna'})
        col_conta  = find_col_by_candidates(df_try, {'conta', 'conta receita'})  # tolera variação simples
        df = df_try
        chosen_info = info
        targets_ok = True
        break
    except KeyError:
        continue

if not targets_ok:
    print("Nenhum arquivo com colunas 'coluna' e 'conta' foi encontrado diretamente.")
    df_dbg, info_dbg = load_table(candidates[0])
    print('Colunas do 1º candidato:', df_dbg.columns.tolist()[:50])
    raise KeyError("Não foi possível localizar as colunas necessárias. "
                   "Verifique se o dataset possui campos 'coluna' e 'conta'.")

print("Arquivo selecionado:", chosen_info['source'])
if chosen_info['sheet'] is not None:
    print("Planilha:", chosen_info['sheet'], "| skiprows:", chosen_info['skiprows'])
print("Dimensão bruta:", df.shape)

# ------------------------
# 4) Filtros (case/acentos-agnósticos)
# ------------------------
def norm_series(s: pd.Series) -> pd.Series:
    return s.astype(str).map(normalize_text)

# Localizar (garantia) os nomes originais
col_coluna = find_col_by_candidates(df, {'coluna'})
col_conta  = find_col_by_candidates(df, {'conta', 'conta receita'})

# Alvos
alvo_coluna_norm = normalize_text('Até o Bimestre (c)')
alvo_conta_norm  = normalize_text('RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)')

# Colunas temporárias normalizadas
col_coluna_norm = '__col_coluna_norm__'
col_conta_norm  = '__col_conta_norm__'

df[col_coluna_norm] = norm_series(df[col_coluna])
df[col_conta_norm]  = norm_series(df[col_conta])

mask = (df[col_coluna_norm] == alvo_coluna_norm) & (df[col_conta_norm] == alvo_conta_norm)
df_filtrado = df.loc[mask].drop(columns=[col_coluna_norm, col_conta_norm])

print("Registros após filtro:", df_filtrado.shape)

# Visualização (amostra)
try:
    display(df_filtrado.head(50))
except Exception:
    print(df_filtrado.head(50))

# ------------------------
# 5) Exportar para Excel e disponibilizar download
# ------------------------
with pd.ExcelWriter(OUT_XLSX, engine='openpyxl') as xlw:
    df_filtrado.to_excel(xlw, index=False, sheet_name='filtrado')

print("Arquivo Excel salvo em:", OUT_XLSX)

# Disparar download (Colab) ou exibir link (Jupyter/VS Code)
if IN_COLAB and colab_files is not None:
    try:
        colab_files.download(OUT_XLSX)
        print("Download iniciado no navegador (Colab).")
    except Exception as e:
        print("Falha ao iniciar download no Colab:", e)
else:
    try:
        display(FileLink(OUT_XLSX))
        print("Link de download exibido acima (Jupyter/VS Code).")
    except Exception:
        print("Para obter o arquivo, acesse o caminho informado.")
# Out:
# Arquivos extraídos para: /content/dados_2025_1bi_mun_rec
# 1 arquivo(s) tabulares encontrado(s).
# [1] /content/dados_2025_1bi_mun_rec/finbraRREO.csv
# ...
# Arquivo selecionado: /content/dados_2025_1bi_mun_rec/finbraRREO.csv
# Dimensão bruta: (982990, 8)
# Registros após filtro: (5452, 8)
#                                             Instituição  Cod.IBGE  UF  \
# 74    Prefeitura Municipal de São Sebastião da Amore...   4126009  PR
# 254        Prefeitura Municipal de Arroio do Tigre - RS   4301206  RS
# 457       Prefeitura Municipal de Nova Roma do Sul - RS   4313359  RS
# 682           Prefeitura Municipal de Ponta Grossa - PR   4119905  PR
# 902           Prefeitura Municipal de José Boiteux - SC   4209151  SC
# 1128      Prefeitura Municipal de Liberato Salzano - RS   4311601  RS
# 1379           Prefeitura Municipal de Campo Largo - PR   4104204  PR
# 1596  Prefeitura Municipal de Monte Alegre dos Campo...   4312377  RS
# 1773       Prefeitura Municipal de Três Cachoeiras - RS   4321667  RS
# 1950        Prefeitura Municipal de Guarujá do Sul - SC   4206603  SC
# 2134    Prefeitura Municipal de São Valério do Sul - RS   4319737  RS
# 2326               Prefeitura Municipal de Gaurama - RS   4308706  RS
# 2543            Prefeitura Municipal de Itapiranga - SC   4208401  SC
# 2772  Prefeitura Municipal de Santa Maria do Herval ...   4316956  RS
# 2965          Prefeitura Municipal de Novo Machado - RS   4313425  RS
# 3183              Prefeitura Municipal de Teutônia - RS   4321451  RS
# 3403           Prefeitura Municipal de Barra Funda - RS   4301958  RS
# 3604            Prefeitura Municipal de Ronda Alta - RS   4316105  RS
# 3792         Prefeitura Municipal de Vicente Dutra - RS   4323101  RS
# 3979            Prefeitura Municipal de Ibiraiaras - RS   4309902  RS
# 4201               Prefeitura Municipal de Cristal - RS   4306056  RS
# 4443            Prefeitura Municipal de Rio do Sul - SC   4214805  SC
# 4669             Prefeitura Municipal de Ji-Paraná - RO   1100122  RO
# 4875        Prefeitura Municipal de Caxambu do Sul - SC   4204103  SC
# 5042            Prefeitura Municipal de Jaboticaba - RS   4310850  RS
# 5221               Prefeitura Municipal de Vargeão - SC   4219101  SC
# 5404          Prefeitura Municipal de Faxinalzinho - RS   4308052  RS
# 5579          Prefeitura Municipal de Santa Helena - SC   4215554  SC
# 5751     Prefeitura Municipal de Diamante do Norte - PR   4107108  PR
# 5935           Prefeitura Municipal de Vidal Ramos - SC   4219200  SC
# 6142  Prefeitura Municipal de Maximiliano de Almeida...   4312203  RS
# 6328              Prefeitura Municipal de Bituruna - PR   4102901  PR
# 6521               Prefeitura Municipal de Tavares - RS   4321352  RS
# 6695              Prefeitura Municipal de Gravatal - SC   4206207  SC
# 6890             Prefeitura Municipal de Tuparendi - RS   4322301  RS
# 7109               Prefeitura Municipal de Rolante - RS   4316006  RS
# 7325            Prefeitura Municipal de Nova Palma - RS   4313102  RS
# 7537              Prefeitura Municipal de Colorado - RS   4305603  RS
# 7748  Prefeitura Municipal de Santo Antônio do Monte...   3160405  MG
# 7947                  Prefeitura Municipal de Imbé - RS   4310330  RS
# 8151                 Prefeitura Municipal de Guapé - MG   3128105  MG
# 8359              Prefeitura Municipal de Cotiporã - RS   4305959  RS
# 8531            Prefeitura Municipal de Erval Seco - RS   4307302  RS
# 8696         Prefeitura Municipal de Enéas Marques - PR   4107405  PR
# 8911            Prefeitura Municipal de Rio Branco - AC   1200401  AC
# 9122  Prefeitura Municipal de Santana da Boa Vista - RS   4317004  RS
# 9307  Prefeitura Municipal de Vista Alegre do Alto - SP   3556909  SP
# 9499     Prefeitura Municipal de Braço do Trombudo - SC   4202859  SC
# 9670            Prefeitura Municipal de Esmeraldas - MG   3124104  MG
# 9811        Prefeitura Municipal de Pinto Bandeira - RS   4314548  RS
#
#       População              Coluna  \
# 74         8070  Até o Bimestre (c)
# 254       12022  Até o Bimestre (c)
# 457        3468  Até o Bimestre (c)
# 682      391654  Até o Bimestre (c)
# 902        5991  Até o Bimestre (c)
# 1128       4664  Até o Bimestre (c)
# 1379     144165  Até o Bimestre (c)
# 1596       3610  Até o Bimestre (c)
# 1773      11551  Até o Bimestre (c)
# 1950       4819  Até o Bimestre (c)
# 2134       2547  Até o Bimestre (c)
# 2326       5676  Até o Bimestre (c)
# 2543      16503  Até o Bimestre (c)
# 2772       6541  Até o Bimestre (c)
# 2965       3198  Até o Bimestre (c)
# 3183      32776  Até o Bimestre (c)
# 3403       2497  Até o Bimestre (c)
# 3604       9750  Até o Bimestre (c)
# 3792       4660  Até o Bimestre (c)
# 3979       6764  Até o Bimestre (c)
# 4201       7352  Até o Bimestre (c)
# 4443      70952  Até o Bimestre (c)
# 4669     136825  Até o Bimestre (c)
# 4875       4614  Até o Bimestre (c)
# 5042       3754  Até o Bimestre (c)
# 5221       3585  Até o Bimestre (c)
# 5404       2521  Até o Bimestre (c)
# 5579       2427  Até o Bimestre (c)
# 5751       5151  Até o Bimestre (c)
# 5935       6160  Até o Bimestre (c)
# 6142       4763  Até o Bimestre (c)
# 6328      15443  Até o Bimestre (c)
# 6521       5554  Até o Bimestre (c)
# 6695      14022  Até o Bimestre (c)
# 6890       8342  Até o Bimestre (c)
# 7109      21288  Até o Bimestre (c)
# 7325       5328  Até o Bimestre (c)
# 7537       3258  Até o Bimestre (c)
# 7748      28345  Até o Bimestre (c)
# 7947      27053  Até o Bimestre (c)
# 8151      13781  Até o Bimestre (c)
# 8359       3850  Até o Bimestre (c)
# 8531       6748  Até o Bimestre (c)
# 8696       5995  Até o Bimestre (c)
# 8911     364368  Até o Bimestre (c)
# 9122       7120  Até o Bimestre (c)
# 9307       8108  Até o Bimestre (c)
# 9499       3954  Até o Bimestre (c)
# 9670     102608  Até o Bimestre (c)
# 9811       2712  Até o Bimestre (c)
#
#                                           Conta  \
# 74    RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 254   RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 457   RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 682   RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 902   RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 1128  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 1379  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 1596  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 1773  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 1950  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 2134  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 2326  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 2543  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 2772  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 2965  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 3183  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 3403  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 3604  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 3792  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 3979  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 4201  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 4443  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 4669  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 4875  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5042  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5221  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5404  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5579  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5751  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 5935  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 6142  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 6328  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 6521  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 6695  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 6890  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 7109  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 7325  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 7537  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 7748  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 7947  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 8151  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 8359  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 8531  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 8696  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 8911  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 9122  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 9307  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 9499  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 9670  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
# 9811  RECEITAS (EXCETO INTRA-ORÇAMENTÁRIAS) (I)
#
#                             Identificador da Conta         Valor
# 74    siconfi-cor_ReceitasExcetoIntraOrcamentarias    8500560,11
# 254   siconfi-cor_ReceitasExcetoIntraOrcamentarias    9237544,17
# 457   siconfi-cor_ReceitasExcetoIntraOrcamentarias    7067188,08
# 682   siconfi-cor_ReceitasExcetoIntraOrcamentarias  317247123,69
# 902   siconfi-cor_ReceitasExcetoIntraOrcamentarias    6738407,94
# 1128  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6255274,44
# 1379  siconfi-cor_ReceitasExcetoIntraOrcamentarias  129836789,34
# 1596  siconfi-cor_ReceitasExcetoIntraOrcamentarias    5644676,57
# 1773  siconfi-cor_ReceitasExcetoIntraOrcamentarias   10774054,98
# 1950  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6741637,52
# 2134  siconfi-cor_ReceitasExcetoIntraOrcamentarias    4836371,06
# 2326  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6782205,79
# 2543  siconfi-cor_ReceitasExcetoIntraOrcamentarias   21877275,27
# 2772  siconfi-cor_ReceitasExcetoIntraOrcamentarias    9012338,81
# 2965  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6489270,64
# 3183  siconfi-cor_ReceitasExcetoIntraOrcamentarias   40281265,07
# 3403  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6208010,93
# 3604  siconfi-cor_ReceitasExcetoIntraOrcamentarias   12364796,75
# 3792  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6576729,83
# 3979  siconfi-cor_ReceitasExcetoIntraOrcamentarias    8986442,18
# 4201  siconfi-cor_ReceitasExcetoIntraOrcamentarias    9656456,78
# 4443  siconfi-cor_ReceitasExcetoIntraOrcamentarias   79875771,17
# 4669  siconfi-cor_ReceitasExcetoIntraOrcamentarias   99072938,56
# 4875  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6355060,00
# 5042  siconfi-cor_ReceitasExcetoIntraOrcamentarias    5345827,51
# 5221  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7817954,88
# 5404  siconfi-cor_ReceitasExcetoIntraOrcamentarias    4404901,33
# 5579  siconfi-cor_ReceitasExcetoIntraOrcamentarias    5530367,77
# 5751  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7943256,19
# 5935  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7786036,09
# 6142  siconfi-cor_ReceitasExcetoIntraOrcamentarias    9704774,38
# 6328  siconfi-cor_ReceitasExcetoIntraOrcamentarias    19801410,4
# 6521  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6035406,31
# 6695  siconfi-cor_ReceitasExcetoIntraOrcamentarias    9659045,69
# 6890  siconfi-cor_ReceitasExcetoIntraOrcamentarias   10624271,12
# 7109  siconfi-cor_ReceitasExcetoIntraOrcamentarias   21372148,17
# 7325  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7865145,93
# 7537  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6255612,94
# 7748  siconfi-cor_ReceitasExcetoIntraOrcamentarias   30841017,39
# 7947  siconfi-cor_ReceitasExcetoIntraOrcamentarias   52662914,96
# 8151  siconfi-cor_ReceitasExcetoIntraOrcamentarias   15862890,91
# 8359  siconfi-cor_ReceitasExcetoIntraOrcamentarias    6459099,27
# 8531  siconfi-cor_ReceitasExcetoIntraOrcamentarias    8143653,61
# 8696  siconfi-cor_ReceitasExcetoIntraOrcamentarias    8645133,97
# 8911  siconfi-cor_ReceitasExcetoIntraOrcamentarias  299254269,55
# 9122  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7962170,63
# 9307  siconfi-cor_ReceitasExcetoIntraOrcamentarias   11364956,11
# 9499  siconfi-cor_ReceitasExcetoIntraOrcamentarias    7053016,32
# 9670  siconfi-cor_ReceitasExcetoIntraOrcamentarias   50347121,95
# 9811  siconfi-cor_ReceitasExcetoIntraOrcamentarias    4579699,05
# Arquivo Excel salvo em: /content/DFLUX_Tabela_ManualPDG.xlsx
# Download iniciado no navegador (Colab).
